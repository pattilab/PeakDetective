# %%
import deimos
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import os
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, KFold
import random as rd
import matplotlib
matplotlib.rcParams['figure.dpi'] = 200
import sys
sys.path.append("../src/")
sys.path.append("D:/metabolome_inference/metabolome_inference/src/")
from integrAitor import rawData,integrAitor,Classifier,Smoother,normalizeMatrix,safeNormalize
import detection_helper
import scipy.stats as stats
import seaborn as sb

# %%
datadir = "../data/mzMLs/plasma/"
resolution = 100
ppm = 10

# %%
files = [x for x in os.listdir(datadir) if ".mzML" in x]
print(files)
raw_data = {}
ms1 = {file:deimos.read_mzml(datadir + file)["ms1"] for file in files}
raw_data = {}
for file in files:
    temp = rawData()
    temp.readRawDataFile(datadir + file,ppm)
    raw_data[file] = temp
# Out:
# ['WU350-075_d7_neg_ID_04.mzML', 'WU350-087_d0_ID_04.mzML', 'WU350-092_d14_neg_ID_04.mzML']

# %%
if __name__ == "__main__":
    # initialize ms1 peak container
    ms1_peaks = {}
    # iterate over ms1 datasets
    for k in ms1.keys():
        # partition data into chunks to limit memory usage
        # more on partitioning/mapping later in this notebook
        partitions = deimos.partition(ms1[k],
                                      split_on='mz',
                                      size=500,
                                      overlap=0.05)

        # map peakpicking algorithm to each partition
        # note that more configuration parameters are available
        ms1_peaks[k] = partitions.map(deimos.peakpick.local_maxima,
                                      dims=['mz', 'retention_time'],bins=[2.7, 3.64],
                                      processes=10)

# %%
ints = []
for file in ms1_peaks:
    ints += list(np.log10(ms1_peaks[file]["intensity"].values))
plt.hist(ints)
plt.xlabel("log10(intensity)")
plt.ylabel("# of features")
# Out:
# Text(0, 0.5, '# of features')

# %%
# threshold by intensity
ms1_peaks_thresh = {key:deimos.threshold(value, threshold=10000) for key,value in ms1_peaks.items()}

# %%
dets = []
for file in ms1_peaks_thresh:
    dets.append(len(ms1_peaks_thresh[file]))
print(np.mean(dets),np.std(dets))
# Out:
# 29981.666666666668 26499.82845646783

# %%
#format X
if __name__ == "__main__":
    X = np.zeros((int(np.sum([len(ms1_peaks_thresh[f]) for f in files])),resolution))
    integ = integrAitor(numCores = 10,resolution=resolution)
    keys = []
    i = 0

    for file in files:
        tmp = integ.makeDataMatrix([raw_data[file]],ms1_peaks_thresh[file]["mz"].values,
                                 ms1_peaks_thresh[file]["retention_time"].values-.5,
                                 ms1_peaks_thresh[file]["retention_time"].values+.5)
        X[i:i+len(tmp),:] = tmp        
        i += len(tmp)
        keys += [[file,ind] for ind in ms1_peaks_thresh[file].index.values]

X = X[:i]
print(X.shape)
# Out:
# forming matrix |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# forming matrix |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# forming matrix |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# (89945, 100)

# %%
if __name__ == "__main__":
    X_smoothed,tics,y,progress = integ.curatePeaks(X)
# Out:
# fitting smoother...
# Epoch 1/10
# 1265/1265 [==============================] - 26s 20ms/step - loss: 0.1637 - mean_absolute_error: 0.0951 - val_loss: 0.0512 - val_mean_absolute_error: 0.0045
# Epoch 2/10
# 1265/1265 [==============================] - 24s 19ms/step - loss: 0.0516 - mean_absolute_error: 0.0038 - val_loss: 0.0495 - val_mean_absolute_error: 0.0024
# Epoch 3/10
# 1265/1265 [==============================] - 25s 19ms/step - loss: 0.0505 - mean_absolute_error: 0.0025 - val_loss: 0.0493 - val_mean_absolute_error: 0.0020
# Epoch 4/10
# 1265/1265 [==============================] - 25s 19ms/step - loss: 0.0502 - mean_absolute_error: 0.0022 - val_loss: 0.0491 - val_mean_absolute_error: 0.0018
# Epoch 5/10
# 1265/1265 [==============================] - 25s 19ms/step - loss: 0.0501 - mean_absolute_error: 0.0021 - val_loss: 0.0491 - val_mean_absolute_error: 0.0017
# Epoch 6/10
# 1265/1265 [==============================] - 25s 19ms/step - loss: 0.0500 - mean_absolute_error: 0.0020 - val_loss: 0.0490 - val_mean_absolute_error: 0.0016
# Epoch 7/10
# 1265/1265 [==============================] - 25s 19ms/step - loss: 0.0499 - mean_absolute_error: 0.0019 - val_loss: 0.0489 - val_mean_absolute_error: 0.0015
# Epoch 8/10
# 1265/1265 [==============================] - 24s 19ms/step - loss: 0.0499 - mean_absolute_error: 0.0018 - val_loss: 0.0489 - val_mean_absolute_error: 0.0015
# Epoch 9/10
# 1265/1265 [==============================] - 24s 19ms/step - loss: 0.0499 - mean_absolute_error: 0.0018 - val_loss: 0.0489 - val_mean_absolute_error: 0.0014
# Epoch 10/10
# 1265/1265 [==============================] - 25s 19ms/step - loss: 0.0497 - mean_absolute_error: 0.0017 - val_loss: 0.0489 - val_mean_absolute_error: 0.0014
# done
# generating synthetic data...done
# classifying peaks...
# round 1: 89945 unclassified features
# Epoch 1/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.5171 - mean_absolute_error: 0.3491 - val_loss: 0.5848 - val_mean_absolute_error: 0.3852
# Epoch 2/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.2543 - mean_absolute_error: 0.1608 - val_loss: 0.4851 - val_mean_absolute_error: 0.2782
# Epoch 3/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.2075 - mean_absolute_error: 0.1143 - val_loss: 0.4006 - val_mean_absolute_error: 0.1939
# Epoch 4/10
# 2530/2530 [==============================] - 12s 5ms/step - loss: 0.1716 - mean_absolute_error: 0.0795 - val_loss: 0.3283 - val_mean_absolute_error: 0.1306
# Epoch 5/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.1400 - mean_absolute_error: 0.0532 - val_loss: 0.2694 - val_mean_absolute_error: 0.0871
# Epoch 6/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.1147 - mean_absolute_error: 0.0353 - val_loss: 0.2184 - val_mean_absolute_error: 0.0562
# Epoch 7/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.0936 - mean_absolute_error: 0.0232 - val_loss: 0.1774 - val_mean_absolute_error: 0.0365
# Epoch 8/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.0755 - mean_absolute_error: 0.0149 - val_loss: 0.1430 - val_mean_absolute_error: 0.0233
# Epoch 9/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.0610 - mean_absolute_error: 0.0097 - val_loss: 0.1156 - val_mean_absolute_error: 0.0150
# Epoch 10/10
# 2530/2530 [==============================] - 13s 5ms/step - loss: 0.0492 - mean_absolute_error: 0.0063 - val_loss: 0.0937 - val_mean_absolute_error: 0.0100
# round 2: 2438 unclassified features
# Epoch 1/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.4879 - mean_absolute_error: 0.3049 - val_loss: 0.0504 - val_mean_absolute_error: 0.0099
# Epoch 2/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0553 - mean_absolute_error: 0.0170 - val_loss: 0.0329 - val_mean_absolute_error: 0.0064
# Epoch 3/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0332 - mean_absolute_error: 0.0117 - val_loss: 0.0143 - val_mean_absolute_error: 0.0032
# Epoch 4/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0173 - mean_absolute_error: 0.0062 - val_loss: 0.0096 - val_mean_absolute_error: 0.0026
# Epoch 5/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0042 - val_loss: 0.0081 - val_mean_absolute_error: 0.0022
# Epoch 6/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0107 - mean_absolute_error: 0.0034 - val_loss: 0.0099 - val_mean_absolute_error: 0.0028
# Epoch 7/10
# 3761/3761 [==============================] - 18s 5ms/step - loss: 0.0094 - mean_absolute_error: 0.0030 - val_loss: 0.0091 - val_mean_absolute_error: 0.0025
# Epoch 8/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0075 - mean_absolute_error: 0.0024 - val_loss: 0.0052 - val_mean_absolute_error: 0.0013
# Epoch 9/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0024 - val_loss: 0.0066 - val_mean_absolute_error: 0.0017
# Epoch 10/10
# 3761/3761 [==============================] - 19s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0023 - val_loss: 0.0076 - val_mean_absolute_error: 0.0019
# round 3: 1241 unclassified features
# Epoch 1/10
# 3778/3778 [==============================] - 20s 5ms/step - loss: 0.4103 - mean_absolute_error: 0.2598 - val_loss: 0.0188 - val_mean_absolute_error: 0.0038
# Epoch 2/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0278 - mean_absolute_error: 0.0088 - val_loss: 0.0108 - val_mean_absolute_error: 0.0025
# Epoch 3/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0160 - mean_absolute_error: 0.0052 - val_loss: 0.0075 - val_mean_absolute_error: 0.0020
# Epoch 4/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0096 - mean_absolute_error: 0.0030 - val_loss: 0.0076 - val_mean_absolute_error: 0.0022
# Epoch 5/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0024 - val_loss: 0.0041 - val_mean_absolute_error: 0.0013
# Epoch 6/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0056 - mean_absolute_error: 0.0019 - val_loss: 0.0050 - val_mean_absolute_error: 0.0016
# Epoch 7/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0051 - mean_absolute_error: 0.0017 - val_loss: 0.0027 - val_mean_absolute_error: 8.1806e-04
# Epoch 8/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0015 - val_loss: 0.0039 - val_mean_absolute_error: 0.0012
# Epoch 9/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0043 - mean_absolute_error: 0.0015 - val_loss: 0.0034 - val_mean_absolute_error: 0.0010
# Epoch 10/10
# 3778/3778 [==============================] - 19s 5ms/step - loss: 0.0041 - mean_absolute_error: 0.0015 - val_loss: 0.0033 - val_mean_absolute_error: 0.0010
# round 4: 816 unclassified features
# Epoch 1/10
# 3784/3784 [==============================] - 19s 5ms/step - loss: 0.4316 - mean_absolute_error: 0.2723 - val_loss: 0.0413 - val_mean_absolute_error: 0.0104
# Epoch 2/10
# 3784/3784 [==============================] - 18s 5ms/step - loss: 0.0447 - mean_absolute_error: 0.0145 - val_loss: 0.0203 - val_mean_absolute_error: 0.0048
# Epoch 3/10
# 3784/3784 [==============================] - 19s 5ms/step - loss: 0.0282 - mean_absolute_error: 0.0095 - val_loss: 0.0125 - val_mean_absolute_error: 0.0032
# Epoch 4/10
# 3784/3784 [==============================] - 19s 5ms/step - loss: 0.0196 - mean_absolute_error: 0.0066 - val_loss: 0.0130 - val_mean_absolute_error: 0.0037
# Epoch 5/10
# 3784/3784 [==============================] - 19s 5ms/step - loss: 0.0138 - mean_absolute_error: 0.0050 - val_loss: 0.0075 - val_mean_absolute_error: 0.0024
# Epoch 6/10
# 3784/3784 [==============================] - 19s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0042 - val_loss: 0.0098 - val_mean_absolute_error: 0.0032
# Epoch 7/10
# 3784/3784 [==============================] - 19s 5ms/step - loss: 0.0087 - mean_absolute_error: 0.0033 - val_loss: 0.0093 - val_mean_absolute_error: 0.0030
# Epoch 8/10
# 3784/3784 [==============================] - 20s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0028 - val_loss: 0.0078 - val_mean_absolute_error: 0.0025
# Epoch 9/10
# 3784/3784 [==============================] - 19s 5ms/step - loss: 0.0072 - mean_absolute_error: 0.0026 - val_loss: 0.0065 - val_mean_absolute_error: 0.0020
# Epoch 10/10
# 3784/3784 [==============================] - 20s 5ms/step - loss: 0.0068 - mean_absolute_error: 0.0025 - val_loss: 0.0069 - val_mean_absolute_error: 0.0022
# round 5: 689 unclassified features
# Epoch 1/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.6030 - mean_absolute_error: 0.4127 - val_loss: 0.0583 - val_mean_absolute_error: 0.0152
# Epoch 2/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0475 - mean_absolute_error: 0.0163 - val_loss: 0.0195 - val_mean_absolute_error: 0.0043
# Epoch 3/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0237 - mean_absolute_error: 0.0087 - val_loss: 0.0114 - val_mean_absolute_error: 0.0030
# Epoch 4/10
# 3785/3785 [==============================] - 19s 5ms/step - loss: 0.0137 - mean_absolute_error: 0.0054 - val_loss: 0.0080 - val_mean_absolute_error: 0.0024
# Epoch 5/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0096 - mean_absolute_error: 0.0038 - val_loss: 0.0072 - val_mean_absolute_error: 0.0022
# Epoch 6/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0074 - mean_absolute_error: 0.0028 - val_loss: 0.0056 - val_mean_absolute_error: 0.0017
# Epoch 7/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0025 - val_loss: 0.0063 - val_mean_absolute_error: 0.0019
# Epoch 8/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0022 - val_loss: 0.0050 - val_mean_absolute_error: 0.0014
# Epoch 9/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0053 - mean_absolute_error: 0.0019 - val_loss: 0.0052 - val_mean_absolute_error: 0.0014
# Epoch 10/10
# 3785/3785 [==============================] - 20s 5ms/step - loss: 0.0052 - mean_absolute_error: 0.0019 - val_loss: 0.0046 - val_mean_absolute_error: 0.0013
# done
# training classifier...
# Epoch 1/10
# 3795/3795 [==============================] - 20s 5ms/step - loss: 0.3719 - mean_absolute_error: 0.2228 - val_loss: 0.0448 - val_mean_absolute_error: 0.0118
# Epoch 2/10
# 3795/3795 [==============================] - 18s 5ms/step - loss: 0.0538 - mean_absolute_error: 0.0175 - val_loss: 0.0278 - val_mean_absolute_error: 0.0064
# Epoch 3/10
# 3795/3795 [==============================] - 19s 5ms/step - loss: 0.0389 - mean_absolute_error: 0.0137 - val_loss: 0.0169 - val_mean_absolute_error: 0.0032
# Epoch 4/10
# 3795/3795 [==============================] - 20s 5ms/step - loss: 0.0271 - mean_absolute_error: 0.0103 - val_loss: 0.0078 - val_mean_absolute_error: 0.0018
# Epoch 5/10
# 3795/3795 [==============================] - 20s 5ms/step - loss: 0.0216 - mean_absolute_error: 0.0085 - val_loss: 0.0064 - val_mean_absolute_error: 0.0016
# Epoch 6/10
# 3795/3795 [==============================] - 20s 5ms/step - loss: 0.0188 - mean_absolute_error: 0.0074 - val_loss: 0.0066 - val_mean_absolute_error: 0.0016
# Epoch 7/10
# 3795/3795 [==============================] - 20s 5ms/step - loss: 0.0162 - mean_absolute_error: 0.0065 - val_loss: 0.0049 - val_mean_absolute_error: 0.0012
# Epoch 8/10
# 3795/3795 [==============================] - 19s 5ms/step - loss: 0.0152 - mean_absolute_error: 0.0059 - val_loss: 0.0043 - val_mean_absolute_error: 0.0010
# Epoch 9/10
# 3795/3795 [==============================] - 19s 5ms/step - loss: 0.0142 - mean_absolute_error: 0.0056 - val_loss: 0.0046 - val_mean_absolute_error: 0.0011
# Epoch 10/10
# 3795/3795 [==============================] - 19s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0050 - val_loss: 0.0056 - val_mean_absolute_error: 0.0013
# done

# %%
print(progress)
plt.plot(list(range(len(progress))),np.log10(progress),color="black")
plt.scatter(list(range(len(progress))),np.log10(progress),color="black")
plt.xlabel("round")
plt.ylabel("log10(# of uncertain peaks)")
# Out:
# [89945, 2438, 1241, 816, 689]
# Text(0, 0.5, 'log10(# of uncertain peaks)')

# %%
pca = PCA(2)
loads = pca.fit_transform(X_smoothed)
plt.scatter(loads[:,0],loads[:,1],c=tics,s=.1,alpha=.5)
plt.xlabel("PC1 (" + str(np.round(100*pca.explained_variance_ratio_[0],2)) + "%)")
plt.ylabel("PC2 (" + str(np.round(100*pca.explained_variance_ratio_[1],2)) + "%)")
plt.colorbar(label="log2(intensity)")

# %%
pca = PCA(2)
loads = pca.fit_transform(X_smoothed)
plt.scatter(loads[:,0],loads[:,1],c=y,s=.1,alpha=.5)
plt.xlabel("PC1 (" + str(np.round(100*pca.explained_variance_ratio_[0],2)) + "%)")
plt.ylabel("PC2 (" + str(np.round(100*pca.explained_variance_ratio_[1],2)) + "%)")
plt.colorbar(label="log2(intensity)")

# %%
ms1_peaks_curated = {file:[] for file in files}
for [file,index],score in zip(keys,y):
    if score > .5:
        ms1_peaks_curated[file].append(index)
for file in ms1_peaks_curated:
    ms1_peaks_curated[file] = ms1_peaks_thresh[file].loc[ms1_peaks_curated[file],:]

# %%
df = {}
for file in ms1_peaks_thresh:
    for index,row in ms1_peaks_thresh[file].iterrows():
        if index in ms1_peaks_curated[file].index.values:
            df[len(df)] = {"sample":file,"classification":"true peak"}
        else:
            df[len(df)] = {"sample":file,"classification":"artifact"}

df = pd.DataFrame.from_dict(df,orient="index")

def aggregate(rows,columns,df):
    column_keys = df[columns].unique()
    row_keys = df[rows].unique()

    agg = { key : [ 100*len(df[(df[rows]==value) & (df[columns]==key)]) / len(df[df[rows]==value]) for value in row_keys]
               for key in column_keys }

    aggdf = pd.DataFrame(agg,index = row_keys)
    aggdf.index.rename(rows,inplace=True)

    return aggdf

aggregate('sample','classification',df).plot(kind='bar',stacked=True,color=["blue","grey"])
plt.xticks([],[])
plt.ylabel("% of features")
# Out:
# Text(0, 0.5, '% of features')

# %%
file = files[0]
inds = list(ms1_peaks_thresh[file].index.values)
rd.shuffle(inds)
for i in inds:
    if i in ms1_peaks_curated[file].index.values:
        integ.plot_overlayedEIC([raw_data[f] for f in files],ms1_peaks_curated[file].at[i,"mz"],ms1_peaks_curated[file].at[i,"retention_time"]-.5,ms1_peaks_curated[file].at[i,"retention_time"] + .5)
        plt.xlabel("RT")
        plt.ylabel("Intensity")
        break

# %%
file = files[0]
inds = list(ms1_peaks_thresh[file].index.values)
rd.shuffle(inds)
for i in inds:
    if i not in ms1_peaks_curated[file].index.values:
        integ.plot_overlayedEIC([raw_data[f] for f in files],ms1_peaks_thresh[file].at[i,"mz"],ms1_peaks_thresh[file].at[i,"retention_time"]-.5,ms1_peaks_thresh[file].at[i,"retention_time"] + .5)
        plt.xlabel("RT")
        plt.ylabel("Intensity")
        break
