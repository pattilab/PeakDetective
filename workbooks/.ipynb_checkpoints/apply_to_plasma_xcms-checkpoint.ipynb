# %%
import deimos
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import os
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, KFold
import random as rd
import matplotlib
matplotlib.rcParams['figure.dpi'] = 200
import sys
sys.path.append("../src/")
sys.path.append("D:/metabolome_inference/metabolome_inference/src/")
from PeakDetective import rawData,PeakDetective,Classifier,Smoother,normalizeMatrix,safeNormalize
import detection_helper
import scipy.stats as stats
import seaborn as sb

# %%
datadir = "../data/mzMLs/plasma/"
resolution = 60

# %%
ms1ppm = 10
peakWidth = (15,83)
s2n = 5
noise = 2
det = detection_helper.PeakList()
#det.runXCMS(datadir, "xcms_peak_list.csv", "negative", ms1ppm, peakWidth,s2n=s2n,noise=noise)
det.readXCMSPeakList(datadir+"xcms_peak_list.csv")
peakList = pd.DataFrame(det.peakList)
peakList["rt"] = .5 * peakList["rt_start"] + .5 * peakList["rt_end"]
peakList = peakList[["mz","rt"]]
peakList
# Out:
#               mz         rt
# 1      69.009257   3.725231
# 2      69.009265   1.295355
# 3      70.945947   5.305746
# 4      70.945928   5.219294
# 5      71.050080   1.217948
# ...          ...        ...
# 5250  879.818163   8.490083
# 5251  887.327660   8.490083
# 5252  889.803276   8.819713
# 5253  889.803118   8.740758
# 5254  889.803216  11.103857
#
# [5254 rows x 2 columns]

# %%
files = [x for x in os.listdir(datadir) if ".mzML" in x]
print(files)
raw_data = []
for file in files:
    temp = rawData()
    temp.readRawDataFile(datadir + file,ms1ppm)
    raw_data.append(temp)
# Out:
# ['WU350-075_d7_neg_ID_04.mzML', 'WU350-087_d0_ID_04.mzML', 'WU350-092_d14_neg_ID_04.mzML']

# %%
#format X
if __name__ == "__main__":
    integ = PeakDetective(numCores = 20,resolution=resolution)
    ms1_peaks_curated,X_norm,X_orig,tics,scores,progress = integ.curatePeaks(raw_data,peakList,min_peaks=10000,shift=2.0,smooth_epochs=20)
# Out:
# generated EICs...
# forming matrix |██████████████████████████████████████████████████| 100.0%
# done
# fitting smoother...
# Epoch 1/20
# 222/222 [==============================] - 6s 23ms/step - loss: 0.6230 - mean_absolute_error: 0.4436 - val_loss: 0.1857 - val_mean_absolute_error: 0.1191
# Epoch 2/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.1410 - mean_absolute_error: 0.0702 - val_loss: 0.1088 - val_mean_absolute_error: 0.0424
# Epoch 3/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.1063 - mean_absolute_error: 0.0390 - val_loss: 0.0910 - val_mean_absolute_error: 0.0282
# Epoch 4/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0919 - mean_absolute_error: 0.0266 - val_loss: 0.0811 - val_mean_absolute_error: 0.0199
# Epoch 5/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0827 - mean_absolute_error: 0.0190 - val_loss: 0.0747 - val_mean_absolute_error: 0.0142
# Epoch 6/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0769 - mean_absolute_error: 0.0140 - val_loss: 0.0717 - val_mean_absolute_error: 0.0114
# Epoch 7/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0726 - mean_absolute_error: 0.0122 - val_loss: 0.0703 - val_mean_absolute_error: 0.0101
# Epoch 8/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0695 - mean_absolute_error: 0.0111 - val_loss: 0.0696 - val_mean_absolute_error: 0.0094
# Epoch 9/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0711 - mean_absolute_error: 0.0103 - val_loss: 0.0692 - val_mean_absolute_error: 0.0091
# Epoch 10/20
# 222/222 [==============================] - 5s 20ms/step - loss: 0.0713 - mean_absolute_error: 0.0097 - val_loss: 0.0688 - val_mean_absolute_error: 0.0086
# Epoch 11/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0666 - mean_absolute_error: 0.0097 - val_loss: 0.0685 - val_mean_absolute_error: 0.0083
# Epoch 12/20
# 222/222 [==============================] - 4s 20ms/step - loss: 0.0654 - mean_absolute_error: 0.0096 - val_loss: 0.0683 - val_mean_absolute_error: 0.0080
# Epoch 13/20
# 222/222 [==============================] - 5s 20ms/step - loss: 0.0699 - mean_absolute_error: 0.0089 - val_loss: 0.0680 - val_mean_absolute_error: 0.0077
# Epoch 14/20
# 222/222 [==============================] - 5s 20ms/step - loss: 0.0698 - mean_absolute_error: 0.0086 - val_loss: 0.0678 - val_mean_absolute_error: 0.0076
# Epoch 15/20
# 222/222 [==============================] - 5s 20ms/step - loss: 0.0674 - mean_absolute_error: 0.0086 - val_loss: 0.0676 - val_mean_absolute_error: 0.0073
# Epoch 16/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0654 - mean_absolute_error: 0.0084 - val_loss: 0.0674 - val_mean_absolute_error: 0.0073
# Epoch 17/20
# 222/222 [==============================] - 5s 20ms/step - loss: 0.0662 - mean_absolute_error: 0.0083 - val_loss: 0.0672 - val_mean_absolute_error: 0.0070
# Epoch 18/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0646 - mean_absolute_error: 0.0083 - val_loss: 0.0671 - val_mean_absolute_error: 0.0068
# Epoch 19/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0654 - mean_absolute_error: 0.0081 - val_loss: 0.0669 - val_mean_absolute_error: 0.0066
# Epoch 20/20
# 222/222 [==============================] - 5s 21ms/step - loss: 0.0660 - mean_absolute_error: 0.0077 - val_loss: 0.0668 - val_mean_absolute_error: 0.0065
# done
# generating synthetic data...done
# classifying peaks...
# round 1: 15762 unclassified features
# Enter classification (1=True Peak, 0=Artifact):
# 1
# Enter classification (1=True Peak, 0=Artifact):
# 1
# Enter classification (1=True Peak, 0=Artifact):
# 0
# round 2: 1633 unclassified features
# Enter classification (1=True Peak, 0=Artifact):
# 0
# Enter classification (1=True Peak, 0=Artifact):
# 0
# Enter classification (1=True Peak, 0=Artifact):
# 0
# round 3: 1039 unclassified features
# Enter classification (1=True Peak, 0=Artifact):
# 1
# Enter classification (1=True Peak, 0=Artifact):
# 0
# Enter classification (1=True Peak, 0=Artifact):
# 1
# round 4: 961 unclassified features
# Enter classification (1=True Peak, 0=Artifact):
# 0
# Enter classification (1=True Peak, 0=Artifact):
# 0
# Enter classification (1=True Peak, 0=Artifact):
# 0
# round 5: 910 unclassified features
# Enter classification (1=True Peak, 0=Artifact):
# 0
# Enter classification (1=True Peak, 0=Artifact):
# 0
# Enter classification (1=True Peak, 0=Artifact):
# 0
# done
# training classifier...
# Epoch 1/10
# 665/665 [==============================] - 3s 4ms/step - loss: 0.7120 - mean_absolute_error: 0.4943 - val_loss: 0.6185 - val_mean_absolute_error: 0.4205
# Epoch 2/10
# 665/665 [==============================] - 3s 4ms/step - loss: 0.5646 - mean_absolute_error: 0.3644 - val_loss: 0.4334 - val_mean_absolute_error: 0.2456
# Epoch 3/10
# 665/665 [==============================] - 2s 4ms/step - loss: 0.2928 - mean_absolute_error: 0.1389 - val_loss: 0.3037 - val_mean_absolute_error: 0.1622
# Epoch 4/10
# 665/665 [==============================] - 2s 4ms/step - loss: 0.1830 - mean_absolute_error: 0.0810 - val_loss: 0.2095 - val_mean_absolute_error: 0.1104
# Epoch 5/10
# 665/665 [==============================] - 2s 4ms/step - loss: 0.1436 - mean_absolute_error: 0.0633 - val_loss: 0.1844 - val_mean_absolute_error: 0.0951
# Epoch 6/10
# 665/665 [==============================] - 3s 4ms/step - loss: 0.1195 - mean_absolute_error: 0.0516 - val_loss: 0.1595 - val_mean_absolute_error: 0.0804
# Epoch 7/10
# 665/665 [==============================] - 2s 4ms/step - loss: 0.1065 - mean_absolute_error: 0.0454 - val_loss: 0.1558 - val_mean_absolute_error: 0.0753
# Epoch 8/10
# 665/665 [==============================] - 2s 4ms/step - loss: 0.0956 - mean_absolute_error: 0.0398 - val_loss: 0.1493 - val_mean_absolute_error: 0.0686
# Epoch 9/10
# 665/665 [==============================] - 2s 4ms/step - loss: 0.0880 - mean_absolute_error: 0.0346 - val_loss: 0.1416 - val_mean_absolute_error: 0.0629
# Epoch 10/10
# 665/665 [==============================] - 3s 4ms/step - loss: 0.0800 - mean_absolute_error: 0.0307 - val_loss: 0.1255 - val_mean_absolute_error: 0.0540
# done
# formatting output...

# %%
ms1_peaks_curated
# Out:
# {'../data/mzMLs/plasma/WU350-075_d7_neg_ID_04.mzML':               mz         rt
#  3      70.945947   5.305746
#  4      70.945928   5.219294
#  5      71.050080   1.217948
#  6      71.013688   2.891141
#  7      71.013710   6.073578
#  ...          ...        ...
#  5249  879.287514   5.130518
#  5251  887.327660   8.490083
#  5252  889.803276   8.819713
#  5253  889.803118   8.740758
#  5254  889.803216  11.103857
#
#  [3415 rows x 2 columns],
#  '../data/mzMLs/plasma/WU350-087_d0_ID_04.mzML':               mz         rt
#  4      70.945928   5.219294
#  5      71.050080   1.217948
#  6      71.013688   2.891141
#  7      71.013710   6.073578
#  10     71.013711   1.655981
#  ...          ...        ...
#  5198  790.774840  12.303975
#  5199  790.831072   8.583641
#  5200  790.830837   8.663339
#  5205  791.738944  12.767714
#  5208  798.759031  12.321413
#
#  [3221 rows x 2 columns],
#  '../data/mzMLs/plasma/WU350-092_d14_neg_ID_04.mzML':               mz         rt
#  3      70.945947   5.305746
#  4      70.945928   5.219294
#  5      71.050080   1.217948
#  6      71.013688   2.891141
#  7      71.013710   6.073578
#  ...          ...        ...
#  5241  878.702212  12.350815
#  5248  878.812666   8.638001
#  5249  879.287514   5.130518
#  5250  879.818163   8.490083
#  5251  887.327660   8.490083
#
#  [3444 rows x 2 columns]}

# %%
print(progress)
plt.plot(list(range(len(progress))),np.log10(progress),color="black")
plt.scatter(list(range(len(progress))),np.log10(progress),color="black")
plt.xlabel("round")
plt.ylabel("log10(# of uncertain peaks)")
# Out:
# [15762, 1633, 1039, 961, 910]
# Text(0, 0.5, 'log10(# of uncertain peaks)')

# %%
pca = PCA(2)
loads = pca.fit_transform(X_norm)
plt.scatter(loads[:,0],loads[:,1],c=tics,s=.1,alpha=.5)
plt.xlabel("PC1 (" + str(np.round(100*pca.explained_variance_ratio_[0],2)) + "%)")
plt.ylabel("PC2 (" + str(np.round(100*pca.explained_variance_ratio_[1],2)) + "%)")
plt.colorbar(label="log10(intensity)")

# %%
pca = PCA(2)
loads = pca.fit_transform(X_norm)
plt.scatter(loads[:,0],loads[:,1],c=scores,s=.1,alpha=.5)
plt.xlabel("PC1 (" + str(np.round(100*pca.explained_variance_ratio_[0],2)) + "%)")
plt.ylabel("PC2 (" + str(np.round(100*pca.explained_variance_ratio_[1],2)) + "%)")
plt.colorbar(label="Peak Score")

# %%
df = {}
for file in files:
    for index,row in peakList.iterrows():
        if index in ms1_peaks_curated[datadir + file].index.values:
            df[len(df)] = {"sample":file,"classification":"true peak"}
        else:
            df[len(df)] = {"sample":file,"classification":"artifact"}

df = pd.DataFrame.from_dict(df,orient="index")

def aggregate(rows,columns,df):
    column_keys = df[columns].unique()
    row_keys = df[rows].unique()

    agg = { key : [ 100*len(df[(df[rows]==value) & (df[columns]==key)]) / len(df[df[rows]==value]) for value in row_keys]
               for key in column_keys }

    aggdf = pd.DataFrame(agg,index = row_keys)
    aggdf.index.rename(rows,inplace=True)

    return aggdf

aggregate('sample','classification',df).plot(kind='bar',stacked=True,color=["grey","blue"])
plt.xticks([],[])
plt.ylabel("% of features")
# Out:
# Text(0, 0.5, '% of features')

# %%
file = datadir + files[0]
print(files)
inds = list(peakList.index.values)
rd.shuffle(inds)
for i in inds:
    if i in ms1_peaks_curated[file].index.values:
        integ.plot_overlayedEIC(raw_data,ms1_peaks_curated[file].at[i,"mz"],ms1_peaks_curated[file].at[i,"rt"]-.5,ms1_peaks_curated[file].at[i,"rt"]+.5)
        plt.xlabel("RT")
        plt.ylabel("Intensity")
        break
# Out:
# ['WU350-075_d7_neg_ID_04.mzML', 'WU350-087_d0_ID_04.mzML', 'WU350-092_d14_neg_ID_04.mzML']

# %%
file = datadir + files[0]
inds = list(peakList.index.values)
rd.shuffle(inds)
for i in inds:
    if i not in ms1_peaks_curated[file].index.values:
        integ.plot_overlayedEIC(raw_data,peakList.at[i,"mz"],peakList.at[i,"rt"]-.5,peakList.at[i,"rt"] + .5)
        plt.xlabel("RT")
        plt.ylabel("Intensity")
        break

# %%
if __name__ == "__main__":
    ms1_peaks_recurse = {}
    for x in range(len(files)):
        rois = integ.roiDetection(raw_data[x],intensityCutuff=1000,numDataPoints=5)
        peaks = integ.detectPeaks(raw_data[x],rois,window=10,cutoff = 0.5,noiseCutoff=4.0)
        ms1_peaks_recurse[files[x]] = pd.DataFrame(data=np.array(peaks),columns=["mz","rt"])
# Out:
# Detecting ROIs |████████------------------------------------------| 17.8% 479 ROIs found
# Detecting ROIs |█████████████████████████████████████████████████-| 99.7% 2191 ROIs found
# 2201  ROIs found
# generating all EICs from ROIs...
# forming matrix |██████████████████████████████████████████████████| 100.0%
# c:\users\ethan\appdata\local\programs\python\python37\lib\site-packages\PeakDetective\__init__.py:495: RuntimeWarning:
#
# divide by zero encountered in log10
#
# c:\users\ethan\appdata\local\programs\python\python37\lib\site-packages\PeakDetective\__init__.py:495: RuntimeWarning:
#
# invalid value encountered in log10
# done,  198090  EICs generated
# smoothing EICs...
# 6191/6191 [==============================] - 38s 6ms/step
# done
# classifying peaks...
# 6191/6191 [==============================] - 8s 1ms/step
# done
# 8488  peaks found
# Detecting ROIs |█████████████████████████████████████████████████-| 99.9% 4439 ROIs found
# 4433  ROIs found
# generating all EICs from ROIs...
# forming matrix |██████████████████████████████████████████████████| 100.0%
# done,  398970  EICs generated
# smoothing EICs...
# 12468/12468 [==============================] - 74s 6ms/step
# done
# classifying peaks...
# 12468/12468 [==============================] - 15s 1ms/step
# done
# 13002  peaks found
# Detecting ROIs |█████████████████████████████████████████████████-| 99.7% 2298 ROIs found
# 2291  ROIs found
# generating all EICs from ROIs...
# forming matrix |██████████████████████████████████████████████████| 100.0%
# done,  203899  EICs generated
# smoothing EICs...
# 6372/6372 [==============================] - 39s 6ms/step
# done
# classifying peaks...
# 6372/6372 [==============================] - 8s 1ms/step
# done
# 8832  peaks found

# %%
ms1_peaks_recurse
# Out:
# {'WU350-075_d7_neg_ID_04.mzML':               mz         rt
#  0      69.009284   0.668823
#  1      69.009284   0.835490
#  2      69.009284   1.835490
#  3      69.009284  13.502156
#  4      69.009284  14.668823
#  ...          ...        ...
#  8483  897.786290   8.502156
#  8484  897.786290   8.835490
#  8485  897.786290  10.335490
#  8486  897.786290  10.502156
#  8487  897.786290  11.835490
#
#  [8488 rows x 2 columns],
#  'WU350-087_d0_ID_04.mzML':                mz         rt
#  0       70.945943   5.168078
#  1       71.011259  12.668078
#  2       71.011259  12.834745
#  3       71.013688   0.668078
#  4       71.013688   1.668078
#  ...           ...        ...
#  12997  791.833494   9.334745
#  12998  792.750007  11.668078
#  12999  792.750007  12.334745
#  13000  792.750007  13.501411
#  13001  797.724364  12.668078
#
#  [13002 rows x 2 columns],
#  'WU350-092_d14_neg_ID_04.mzML':               mz         rt
#  0      69.009281   0.668811
#  1      69.009281   1.168811
#  2      69.009281  13.002145
#  3      69.009281  14.335478
#  4      71.013704   0.502145
#  ...          ...        ...
#  8827  889.803056  14.335478
#  8828  897.786746   8.668811
#  8829  897.786746  11.168811
#  8830  897.786746  11.835478
#  8831  897.786746  12.002145
#
#  [8832 rows x 2 columns]}

# %%
#X_tot = self.makeDataMatrix([rawData],rois,rt_starts,rt_ends,0)

uniqueFeatures = {}
mzTol = 20
rtTol = 10/60

labels = []
X_all = []

for x in range(len(files)):
    print(x)
    xcms_peaks_curated = ms1_peaks_curated[datadir + files[x]]
    tmp = [x for x in peakList.index.values if x not in xcms_peaks_curated.index.values]
    xcms_peaks_not_curated = peakList.loc[tmp,:]
    inXCMS = []
    for index,row in ms1_peaks_recurse[files[x]].iterrows():
        minMz = row["mz"] - mzTol * row["mz"] / 1e6
        maxMz = row["mz"] + mzTol * row["mz"] / 1e6
        unique = True
        for index2,row2 in peakList.iterrows():
            if row2["mz"] > minMz and row2['mz'] < maxMz:
                if np.abs(row2["rt"] - row["rt"]):
                    unique = False
                    break
        
        inXCMS.append(not unique)
        
    ms1_peaks_recurse[files[x]]["found in xcms"] = inXCMS
    
    newFeats = ms1_peaks_recurse[files[x]][ms1_peaks_recurse[files[x]]["found in xcms"] == False]
    
    tmp = integ.makeDataMatrix([raw_data[x]],xcms_peaks_not_curated["mz"].values,xcms_peaks_not_curated["rt"].values - .5, xcms_peaks_not_curated["rt"].values + .5)
    X_all += list(tmp)
    labels += [0 for _ in range(len(tmp))]
    
    tmp = integ.makeDataMatrix([raw_data[x]],xcms_peaks_curated["mz"].values,xcms_peaks_curated["rt"].values - .5, xcms_peaks_curated["rt"].values + .5)
    X_all += list(tmp)
    labels += [1 for _ in range(len(tmp))]
    
    tmp = integ.makeDataMatrix([raw_data[x]],newFeats["mz"].values,newFeats["rt"].values - .5, newFeats["rt"].values + .5)
    X_all += list(tmp)
    labels += [2 for _ in range(len(tmp))]
# Out:
# 0
# forming matrix |██████████████████████████████████████████████████| 100.0%
# forming matrix |██████████████████████████████████████████████████| 100.0%
# forming matrix |██████████████████████████████████████████████████| 100.0%
# 1
# forming matrix |██████████████████████████████████████████████████| 100.0%
# forming matrix |██████████████████████████████████████████████████| 100.0%
# forming matrix |██████████████████████████████████████████████████| 100.0%
# 2
# forming matrix |██████████████████████████████████████████████████| 100.0%
# forming matrix |██████████████████████████████████████████████████| 100.0%
# forming matrix |██████████████████████████████████████████████████| 100.0%

# %%
X_all_norm = integ.smoother.predict(normalizeMatrix(X_all))

# %%
pca = PCA(2)
loads = pca.fit_transform(X_all_norm)
plt.scatter(loads[:,0],loads[:,1],c=labels,s=.1,alpha=.5)
plt.xlabel("PC1 (" + str(np.round(100*pca.explained_variance_ratio_[0],2)) + "%)")
plt.ylabel("PC2 (" + str(np.round(100*pca.explained_variance_ratio_[1],2)) + "%)")
plt.colorbar(label="classification")
#plt.xlim((-2,2))
#plt.ylim((-2,2))

# %%
for x in range(len(files)):
    print(ms1_peaks_recurse[files[x]][ms1_peaks_recurse[files[x]]["found in xcms"] == False])
# Out:
#               mz         rt  found in xcms
# 98     76.987515   0.502156          False
# 99     76.987515   0.668823          False
# 100    76.987515   1.668823          False
# 101    76.987515   5.835490          False
# 102    76.987515   6.335490          False
# ...          ...        ...            ...
# 8483  897.786290   8.502156          False
# 8484  897.786290   8.835490          False
# 8485  897.786290  10.335490          False
# 8486  897.786290  10.502156          False
# 8487  897.786290  11.835490          False
#
# [1329 rows x 3 columns]
#                mz         rt  found in xcms
# 78      76.987498   0.668078          False
# 79      76.987498   6.501411          False
# 80      76.987498   7.168078          False
# 81      76.987498   7.334745          False
# 82      76.987498   7.668078          False
# ...           ...        ...            ...
# 12996  791.833494   8.668078          False
# 12997  791.833494   9.334745          False
# 12998  792.750007  11.668078          False
# 12999  792.750007  12.334745          False
# 13000  792.750007  13.501411          False
#
# [3868 rows x 3 columns]
#               mz         rt  found in xcms
# 84     76.987506   0.668811          False
# 85     76.987506   6.502145          False
# 86     76.987506   7.168811          False
# 87     76.987506   8.168811          False
# 88     76.987506   8.835478          False
# ...          ...        ...            ...
# 8808  856.776012  13.502145          False
# 8828  897.786746   8.668811          False
# 8829  897.786746  11.168811          False
# 8830  897.786746  11.835478          False
# 8831  897.786746  12.002145          False
#
# [1213 rows x 3 columns]

# %%
sizes 
plt.scatter(ms1_peaks_recurse[files[x]][ms1_peaks_recurse[files[x]]["found in xcms"] == False]["rt"],ms1_peaks_recurse[files[x]][ms1_peaks_recurse[files[x]]["found in xcms"] == False]["mz"],s=1,color="green",label="PeakDetective")
plt.scatter(ms1_peaks_curated[datadir + files[x]]["rt"],ms1_peaks_curated[datadir + files[x]]["mz"],s=1,color="blue",label="XCMS true peaks")
tmp = [y for y in peakList.index.values if y not in ms1_peaks_curated[datadir + files[x]].index.values]
xcms_peaks_not_curated = peakList.loc[tmp,:]
plt.scatter(xcms_peaks_not_curated["rt"],xcms_peaks_not_curated["mz"],s=1,color="black",label="XCMS artifacts")
plt.xlabel("RT")
plt.ylabel("m/z")
plt.legend()
